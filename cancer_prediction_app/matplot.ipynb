# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[2,3,6,9,12]

plt.plot(x,y)

plt.show()

# %%
plt.bar(x,y,color='yellow')
plt.show()

# %%
plt.hist(x, bins=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.hist(x,y,bins=3)
#       2 plt.show()
#
# File c:\Users\indal\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:477, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     471 if len(args) > name_idx:
#     472     warn_deprecated(
#     473         since, message="Passing the %(name)s %(obj_type)s "
#     474         "positionally is deprecated since Matplotlib %(since)s; the "
#     475         "parameter will become keyword-only in %(removal)s.",
#     476         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 477 return func(*args, **kwargs)
#
# TypeError: hist() got multiple values for argument 'bins'
